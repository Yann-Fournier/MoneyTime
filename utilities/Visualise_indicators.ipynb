# %%
import pandas as pd
from Function import rsi, macd, stochastique, bollinger_bands, moyenne_mobile # pour les indicateurs
from Function import simple_plot, plot_rsi, plot_macd, plot_stochastique, plot_bollinger_bands, plot_moyenne_mobile # pour les graphiques

# %%
df_1h = pd.read_csv("../database/binance/1d/BTC-USDT-USDT.csv", sep=",", parse_dates=["date"], index_col="date")
df_1h.index = pd.to_datetime(df_1h.index, unit='ms')
print(df_1h.shape)
df_1h.head()
# Out:
# (2120, 5)
# C:\Users\yfour\AppData\Local\Temp\ipykernel_30616\824048681.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_1h = pd.read_csv("../database/binance/1d/BTC-USDT-USDT.csv", sep=",", parse_dates=["date"], index_col="date")
#                 open      high       low     close     volume
# date
# 2019-09-08  10000.00  10412.65  10000.00  10391.63   3096.291
# 2019-09-09  10316.62  10475.54  10077.22  10307.00  14824.373
# 2019-09-10  10307.00  10382.97   9940.87  10102.02   9068.955
# 2019-09-11  10094.27  10293.11   9884.31  10159.55  10897.922
# 2019-09-12  10163.06  10450.13  10042.12  10415.13  15609.634

# %%
df_1h.rename(columns={"date": "index"}, inplace=True)

# %% [markdown]
# ### Ajout des indicateurs dans le dataframe
# ---

# %%
df_1h = rsi(df_1h)
df_1h = macd(df_1h)
df_1h = stochastique(df_1h)
df_1h = bollinger_bands(df_1h)
df_1h = moyenne_mobile(df_1h)

# %%
print(df_1h.shape)
df_1h.tail()
# Out:
# (2120, 17)
#                 open      high       low     close      volume        rsi  \
# date
# 2025-06-21  103246.1  103940.6  100789.9  102079.8  120771.350  40.871635
# 2025-06-22  102079.8  103362.6   98115.4  100904.7  293562.636  37.898326
# 2025-06-23  100904.7  106050.0   99547.6  105290.9  297222.041  51.949541
# 2025-06-24  105291.0  106239.0  104570.8  106034.9  144449.887  53.856706
# 2025-06-25  106034.9  106750.9  105755.6  106618.6   36764.281  55.353893
#
#                 rsima        macd   macd_diff  macd_signal   stoch_%K  \
# date
# 2025-06-21  50.716976 -420.028812 -648.204233   228.175421  13.077243
# 2025-06-22  48.886819 -669.826438 -718.401487    48.575049  22.766451
# 2025-06-23  48.059349 -508.007183 -445.265786   -62.741397  58.649241
# 2025-06-24  47.733350 -316.086032 -202.675708  -113.410324  73.433414
# 2025-06-25  48.085185 -115.555376   -1.716041  -113.839335  78.845762
#
#              stoch_%D     lower_band    higher_band     ma_band  \
# ...

# %% [markdown]
# ### Graphique
# ---

# %%
simple_plot(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 1 Axes>

# %%
plot_rsi(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 2 Axes>

# %%
plot_macd(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 2 Axes>

# %%
plot_stochastique(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 2 Axes>

# %%
plot_bollinger_bands(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 1 Axes>

# %%
plot_moyenne_mobile(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 1 Axes>
