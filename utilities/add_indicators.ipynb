# %%
import pandas as pd
from function import rsi, macd, stochastique, bollinger_bands, moyenne_mobile, plot_rsi, plot_macd, plot_stochastique, plot_bollinger_bands, plot_moyenne_mobile

# %%
df_1h = pd.read_csv("../database/binance/1d/BTC-USDT-USDT.csv", sep=",", parse_dates=["date"], index_col="date")
df_1h.index = pd.to_datetime(df_1h.index, unit='ms')
print(df_1h.shape)
df_1h.head()
# Out:
# (2075, 5)
# C:\Users\yfour\AppData\Local\Temp\ipykernel_22196\824048681.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_1h = pd.read_csv("../database/binance/1d/BTC-USDT-USDT.csv", sep=",", parse_dates=["date"], index_col="date")
#                 open      high       low     close     volume
# date
# 2019-09-08  10000.00  10412.65  10000.00  10391.63   3096.291
# 2019-09-09  10316.62  10475.54  10077.22  10307.00  14824.373
# 2019-09-10  10307.00  10382.97   9940.87  10102.02   9068.955
# 2019-09-11  10094.27  10293.11   9884.31  10159.55  10897.922
# 2019-09-12  10163.06  10450.13  10042.12  10415.13  15609.634

# %%
df_1h.rename(columns={"date": "index"}, inplace=True)

# %% [markdown]
# ### Ajout des indicateurs dans le dataframe
# ---

# %%
df_1h = rsi(df_1h)
df_1h = macd(df_1h)
df_1h = stochastique(df_1h)
df_1h = bollinger_bands(df_1h)
df_1h = moyenne_mobile(df_1h)

# %%
print(df_1h.shape)
df_1h.tail()
# Out:
# (2075, 17)
#                 open      high       low     close      volume        rsi  \
# date
# 2025-05-09  103228.0  104373.0  102240.0  102941.9  172883.922  74.731533
# 2025-05-10  102941.9  105000.1  102784.0  104788.8  104384.537  76.935929
# 2025-05-11  104788.8  104950.0  103283.3  104072.7  139136.421  74.231870
# 2025-05-12  104072.7  105863.1  100678.0  102739.3  256542.699  69.344550
# 2025-05-13  102739.3  103930.1  101400.0  103729.9   80713.523  70.878519
#
#                 rsima         macd   macd_diff  macd_signal   stoch_%K  \
# date
# 2025-05-09  67.421606  3569.717433  567.986929  3001.730504  87.740084
# 2025-05-10  67.985649  3915.520965  731.032369  3184.488596  98.282128
# 2025-05-11  68.570789  4084.703551  720.171964  3364.531587  92.460224
# 2025-05-12  68.652961  4064.336590  559.844003  3504.492588  75.998463
# 2025-05-13  69.037886  4081.084566  461.273583  3619.810983  83.609681
#
#              stoch_%D    lower_band    higher_band    ma_band           sma9  \
# date
# 2025-05-09  88.139344  86062.454288  103704.965712  94883.710   97549.111111
# 2025-05-10  92.246749  87279.918032  104452.501968  95866.210   98478.611111
# 2025-05-11  92.827479  88364.695150  105028.394850  96696.545   99283.222222
# 2025-05-12  88.913605  88513.570781  105812.959219  97163.265  100053.888889
# 2025-05-13  84.022789  88652.314119  106683.995881  97668.155  101109.411111
#
#                    sma21
# date
# 2025-05-09  94415.290476
# 2025-05-10  95355.380952
# 2025-05-11  96256.995238
# 2025-05-12  96984.295238
# 2025-05-13  97475.961905

# %% [markdown]
# ### Graphique
# ---

# %%
plot_rsi(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 2 Axes>

# %%
plot_macd(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 2 Axes>

# %%
plot_stochastique(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 2 Axes>

# %%
plot_bollinger_bands(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 1 Axes>

# %%
plot_moyenne_mobile(df_1h, "Bitcoin")
# Out:
# <Mpf_Figure size 2000x1500 with 1 Axes>
